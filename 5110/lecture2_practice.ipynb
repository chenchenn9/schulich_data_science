# %%
pip install oct2py
# Out:
# Collecting oct2py
#   Downloading oct2py-5.6.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 290.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from oct2py) (1.24.3)
# Collecting octave-kernel>=0.34.0 (from oct2py)
#   Downloading octave_kernel-0.35.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: scipy>=0.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from oct2py) (1.10.1)
# Requirement already satisfied: ipykernel in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from octave-kernel>=0.34.0->oct2py) (6.23.0)
# Requirement already satisfied: jupyter-client>=4.3.0 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from octave-kernel>=0.34.0->oct2py) (8.2.0)
# Collecting metakernel>=0.24.0 (from octave-kernel>=0.34.0->oct2py)
#   Obtaining dependency information for metakernel>=0.24.0 from https://files.pythonhosted.org/packages/ad/55/f85425e94b7efc26d61b4760f162cf2cddeefea55e5d3dbc26c7f69cfc94/metakernel-0.30.1-py3-none-any.whl.metadata
#   Downloading metakernel-0.30.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (2.8.2)
# Requirement already satisfied: pyzmq>=23.0 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (25.0.2)
# Requirement already satisfied: tornado>=6.2 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (6.3.1)
# Requirement already satisfied: traitlets>=5.3 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (5.9.0)
# Requirement already satisfied: jedi>=0.18 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.18.2)
# Requirement already satisfied: pexpect>=4.8 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (4.8.0)
# Requirement already satisfied: appnope in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (8.13.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (1.5.6)
# Requirement already satisfied: packaging in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (23.1)
# Requirement already satisfied: psutil in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipykernel->octave-kernel>=0.34.0->oct2py) (5.9.5)
# Requirement already satisfied: backcall in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.0)
# Requirement already satisfied: decorator in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.15.1)
# Requirement already satisfied: stack-data in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from jedi>=0.18->metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (3.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from pexpect>=4.8->metakernel>=0.24.0->octave-kernel>=0.34.0->oct2py) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->jupyter-client>=4.3.0->octave-kernel>=0.34.0->oct2py) (1.16.0)
# Requirement already satisfied: wcwidth in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (2.2.1)
# Requirement already satisfied: pure-eval in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->octave-kernel>=0.34.0->oct2py) (0.2.2)
# Downloading metakernel-0.30.1-py3-none-any.whl (217 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.8/217.8 kB 4.5 MB/s eta 0:00:0000:01
# Installing collected packages: metakernel, octave-kernel, oct2py
# Successfully installed metakernel-0.30.1 oct2py-5.6.0 octave-kernel-0.35.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import sklearn as sl
import scipy as sp
import seaborn as sb
import matplotlib as mpl
from matplotlib import pyplot as plt
import oct2py as oclib

# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.4 MB/s eta 0:00:0000:0100:010m
# Requirement already satisfied: scipy>=1.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlxtend) (1.10.1)
# Requirement already satisfied: numpy>=1.16.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlxtend) (2.0.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from mlxtend) (63.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /Users/dongchen/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
year_list = [1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
       2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
josb_assets_list = [101.783,90.671,81.41,77.144,82.515,84.751,88.954,108.457,133.993,186.511,231.83,
                 304.832,368.392,440.098,491.366,556.364,662.037,813.612,894.847,935.738]
mw_assets_list = [160.494,204.105,295.478,379.415,403.732,611.195,707.734,717.869,769.313,869.198,993.322,
               1123.274,1096.952,1256.467,1187.73,1232.106,1320.318,1405.952,1496.347,1555.23]

# %%
plt.figure(figsize=(24,16), dpi= 40)
plt.plot(year_list,josb_assets_list,label="Joseph A Bank",linewidth=8)
plt.plot(year_list,mw_assets_list,'r--',label="Men's Wearhouse",linewidth=8,color = 'green')
xtick_location = np.arange(1994,2013,4)
plt.xticks(ticks=xtick_location, rotation=0, fontsize=50, horizontalalignment='center')
plt.legend(bbox_to_anchor=(0.50, 0.95),fontsize=50)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.xlabel('Year', fontsize = 65)
plt.ylabel('Total Assets', fontsize = 65)
# Out:
# /var/folders/6m/hf0hqkzn3tv28lnjyh7tf5qm0000gn/T/ipykernel_88736/3988376412.py:3: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(year_list,mw_assets_list,'r--',label="Men's Wearhouse",linewidth=8,color = 'green')
# Text(0, 0.5, 'Total Assets')

# %%
random_values = np.random.normal(1000,200,10000)
bins = np.linspace(400,1600,30)
plt.figure(figsize=(24,16), dpi= 40)
plt.hist(random_values,bins)
plt.xlabel('Total Assets', fontsize = 65)
plt.ylabel('Frequency', fontsize = 65)
plt.xticks(fontsize=50)
plt.yticks(fontsize=50)
plt.grid(axis='both')
plt.title('Histogram of Asset Values in NYSE', fontsize = 65)
# Out:
# Text(0.5, 1.0, 'Histogram of Asset Values in NYSE')

# %%
DataTable = pd.DataFrame(np.random.normal(14,4,[8,3]), columns=list(['c1','c2','c3']))
DataTable[DataTable['c1']>12]
# Out:
#           c1         c2         c3
# 0  19.609394  18.127890  12.482582
# 1  17.956011   8.856658  15.301268
# 3  18.489090  14.332789  10.468571
# 5  13.421659   5.957056  17.085705
# 7  18.661107  14.465762  12.760890

# %%
input_table = pd.read_csv('/Users/dongchen/Downloads/sales_data.csv')input_table.head()
# Out:
#     Order ID  Product ID  Amount (kg) Order Confirm Date
# 0  1005781.0   8908023.0      20000.0                NaN  \
# 1  1005998.0   8909373.0       6297.0                NaN
# 2  1005969.0   8908023.0      20000.0         2020-05-29
# 3  1005969.0   8908023.0      20000.0         2020-05-29
# 4        NaN         NaN          NaN                NaN
#
#   Required Delivery Date
# 0             2020-07-30
# 1             2020-07-15
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
shopping_basket = pd.read_csv("/Users/dongchen/Downloads/small_dataset.csv")
shopping_basket.head()
# Out:
#    Transaction ID             ItemsPurchased
# 0               1         biscuit,bread,milk
# 1               2  biscuit,bread,cereal,milk
# 2               3                  bread,tea
# 3               4             bread,jam,milk
# 4               5                biscuit,tea

# %%
#create a list that contain list of items in each transction
transaction_list = list(shopping_basket["ItemsPurchased"].apply(lambda t:t.split(",")))
#
encoder = TransactionEncoder().fit(transaction_list)
encoded_transaction_list = encoder.transform(transaction_list)
ideal_format_table = pd.DataFrame(encoded_transaction_list, columns = encoder.columns_)
ideal_format_table.head()
# Out:
#    biscuit  bread  cereal    jam   milk    tea
# 0     True   True   False  False   True  False
# 1     True   True    True  False   True  False
# 2    False   True   False  False  False   True
# 3    False   True   False   True   True  False
# 4     True  False   False  False  False   True
