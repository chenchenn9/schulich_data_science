# %%
pip install SQLAlchemy
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as sa
import pandas as pd
import requests, json

# %%
resource_id = '61d62c0e-784a-4061-8bbe-8ee8a42afde7'
limit = 100
api_url = 'https://data.ontario.ca/api/3/action/datastore_search?resource_id={}&limit={}'.format(resource_id, limit)
print(api_url)
# Out:
# https://data.ontario.ca/api/3/action/datastore_search?resource_id=61d62c0e-784a-4061-8bbe-8ee8a42afde7&limit=100

# %%
data = requests.get(api_url).json()

# %%
data
# Out:
# {'help': 'https://data.ontario.ca/api/3/action/help_show?name=datastore_search',
#  'success': True,
#  'result': {'include_total': True,
#   'limit': 100,
#   'records_format': 'objects',
#   'resource_id': '61d62c0e-784a-4061-8bbe-8ee8a42afde7',
#   'total_estimation_threshold': None,
#   'records': [{'_id': 1,
#     'WMU': '2',
#     'Year': 2006,
#     'Active Hunters': 309,
#     'Bull Harvest': 35,
#     'Cow Harvest': 16,
#     'Calf Harvest': 9,
#     'Total Harvest': 60},
#    {'_id': 2,
#     'WMU': '2',
#     'Year': 2007,
#     'Active Hunters': 402,
#     'Bull Harvest': 35,
#     'Cow Harvest': 11,
#     'Calf Harvest': 36,
#     'Total Harvest': 82},
#    {'_id': 3,
#     'WMU': '2',
#     'Year': 2008,
#     'Active Hunters': 349,
#     'Bull Harvest': 29,
#     'Cow Harvest': 12,
#     'Calf Harvest': 11,
#     'Total Harvest': 52},
#    {'_id': 4,
#     'WMU': '2',
#     'Year': 2009,
#     'Active Hunters': 311,
#     'Bull Harvest': 25,
#     'Cow Harvest': 10,
# ...

# %%
moose_data = data['result']['records']

# %%
moose_harvest = pd.DataFrame(moose_data)

# %%
moose_harvest
# Out:
#     _id WMU  Year  Active Hunters  Bull Harvest  Cow Harvest  Calf Harvest
# 0     1   2  2006             309            35           16             9  \
# 1     2   2  2007             402            35           11            36
# 2     3   2  2008             349            29           12            11
# 3     4   2  2009             311            25           10            11
# 4     5   2  2010             380            31           10             5
# ..  ...  ..   ...             ...           ...          ...           ...
# 95   96   8  2016             121             6            4             0
# 96   97   8  2017             187             3            6             3
# 97   98   8  2018             198             5            5             2
# 98   99   8  2019             195             5            0             1
# 99  100   8  2020             184             5            1             1
#
#     Total Harvest
# 0              60
# 1              82
# ...

# %%
moose_harvest.info
# Out:
# <bound method DataFrame.info of     _id WMU  Year  Active Hunters  Bull Harvest  Cow Harvest  Calf Harvest
# 0     1   2  2006             309            35           16             9  \
# 1     2   2  2007             402            35           11            36
# 2     3   2  2008             349            29           12            11
# 3     4   2  2009             311            25           10            11
# 4     5   2  2010             380            31           10             5
# ..  ...  ..   ...             ...           ...          ...           ...
# 95   96   8  2016             121             6            4             0
# 96   97   8  2017             187             3            6             3
# 97   98   8  2018             198             5            5             2
# 98   99   8  2019             195             5            0             1
# 99  100   8  2020             184             5            1             1
#
#     Total Harvest
# ...

# %%
moose_harvest.describe()
# Out:
#               _id         Year  Active Hunters  Bull Harvest  Cow Harvest
# count  100.000000   100.000000      100.000000    100.000000   100.000000  \
# mean    50.500000  2013.850000      805.220000     52.670000    27.970000
# std     29.011492     4.854187      613.694041     49.780945    21.325498
# min      1.000000  2006.000000        3.000000      0.000000     0.000000
# 25%     25.750000  2010.000000      295.000000     17.750000     7.750000
# 50%     50.500000  2014.000000      819.500000     39.500000    27.500000
# 75%     75.250000  2018.000000     1099.750000     68.250000    44.000000
# max    100.000000  2022.000000     2725.000000    218.000000    83.000000
#
#        Calf Harvest  Total Harvest
# count    100.000000     100.000000
# mean      21.270000     101.910000
# std       27.401561      93.565414
# min        0.000000       0.000000
# 25%        2.000000      31.000000
# 50%       10.000000      88.000000
# 75%       30.000000     141.500000
# ...

# %%
moose_harvest
# Out:
#     _id WMU  Year  Active Hunters  Bull Harvest  Cow Harvest  Calf Harvest
# 0     1   2  2006             309            35           16             9  \
# 1     2   2  2007             402            35           11            36
# 2     3   2  2008             349            29           12            11
# 3     4   2  2009             311            25           10            11
# 4     5   2  2010             380            31           10             5
# ..  ...  ..   ...             ...           ...          ...           ...
# 95   96   8  2016             121             6            4             0
# 96   97   8  2017             187             3            6             3
# 97   98   8  2018             198             5            5             2
# 98   99   8  2019             195             5            0             1
# 99  100   8  2020             184             5            1             1
#
#     Total Harvest
# 0              60
# 1              82
# ...

# %% [markdown]
# # Feature Engineering

# %%
# How much percentage that 'Bull Harvest' that takes in 'Total Harvest'
